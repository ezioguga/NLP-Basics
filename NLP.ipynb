# %%
import nltk

# %%
text = "This is a simple sentence, isn't it?"

# %%
tokenizer = nltk.tokenize.WhitespaceTokenizer()

# %%
tokenizer.tokenize(text)
# Out:
# ['This', 'is', 'a', 'simple', 'sentence,', "isn't", 'it?']

# %%
tokenizer = nltk.tokenize.TreebankWordTokenizer()

# %%
tokenizer.tokenize(text)
# Out:
# ['This', 'is', 'a', 'simple', 'sentence', ',', 'is', "n't", 'it', '?']

# %%
text = "A wolf walked away from a pack of walking wolves"

# %%
tokens = tokenizer.tokenize(text)

# %%
stemmer = nltk.stem.PorterStemmer()

# %%
for token in tokens:
  print(stemmer.stem(token))
# Out:
# A
# wolf
# walk
# away
# from
# a
# pack
# of
# walk
# wolv

# %%
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
for token in tokens:
  print(lemmatizer.lemmatize(token))
# Out:
# A
# wolf
# walked
# away
# from
# a
# pack
# of
# walking
# wolf

# %%
import spacy

# %%
spc = spacy.load('en')

# %%
doc = spc(text)

# %%
for token in doc:
  print(token, token.lemma_)
# Out:
# A a
# wolf wolf
# walked walk
# away away
# from from
# a a
# pack pack
# of of
# walking walk
# wolves wolf

# %%
text = "Sri Lankan Airlines will lose $50 million due to Covid-19"

# %%
doc = spc(text)

# %%
for token in doc:
  print(token, token.pos_)
# Out:
# Sri PROPN
# Lankan PROPN
# Airlines PROPN
# will VERB
# lose VERB
# $ SYM
# 50 NUM
# million NUM
# due ADP
# to ADP
# Covid-19 NOUN

# %%
from spacy import displacy

# %%
displacy.render(doc, jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4d53810c888f448289f355ea4d88f7c2-0" class="displacy" width="1975" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Sri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Lankan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Airlines</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">will</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">lose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">50</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">million</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">due</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Covid-19</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-0" stroke-width="2px" d="M70,264.5 C70,89.5 395.0,89.5 395.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-2" stroke-width="2px" d="M420,264.5 C420,89.5 745.0,89.5 745.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,266.5 L587,254.5 603,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-4" stroke-width="2px" d="M945,264.5 C945,89.5 1270.0,89.5 1270.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-5" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,266.5 L1112,254.5 1128,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-6" stroke-width="2px" d="M770,264.5 C770,2.0 1275.0,2.0 1275.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1275.0,266.5 L1283.0,254.5 1267.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-7" stroke-width="2px" d="M1295,264.5 C1295,177.0 1440.0,177.0 1440.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4d53810c888f448289f355ea4d88f7c2-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1440.0,266.5 L1448.0,254.5 1432.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4d53810c888f448289f355ea4d88f7c2-0-8" stroke-width="2px" d="M1470,264.5 C1470,177.0 1615.0,177.0 1615.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sri Lankan Airlines
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  will lose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $50 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  due to Covid-19</div></span>

# %%
texts = ["good movie",
         "not a good movie",
         "did not like",
         "like it",
         "good one"]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(ngram_range=(1,2))

# %%
import pandas as pd

# %%
features = tfidf.fit_transform(texts)

# %%
pd.DataFrame(features.todense(), columns=tfidf.get_feature_names())
# Out:
#        did  did not      good  ...  not good  not like      one
# 0  0.00000  0.00000  0.506204  ...  0.000000   0.00000  0.00000
# 1  0.00000  0.00000  0.363135  ...  0.542226   0.00000  0.00000
# 2  0.48214  0.48214  0.000000  ...  0.000000   0.48214  0.00000
# 3  0.00000  0.00000  0.000000  ...  0.000000   0.00000  0.00000
# 4  0.00000  0.00000  0.427993  ...  0.000000   0.00000  0.63907
#
# [5 rows x 13 columns]

# %%
df = pd.read_csv('/content/IMDB Dataset.csv')

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df['sentiment'].value_counts()
# Out:
# negative    25000
# positive    25000
# Name: sentiment, dtype: int64

# %%
X = df['review']
y = df['sentiment']

# %%
X.head()
# Out:
# 0    One of the other reviewers has mentioned that ...
# 1    A wonderful little production. <br /><br />The...
# 2    I thought this was a wonderful way to spend ti...
# 3    Basically there's a family where a little boy ...
# 4    Petter Mattei's "Love in the Time of Money" is...
# Name: review, dtype: object

# %%
y.head()
# Out:
# 0    positive
# 1    positive
# 2    positive
# 3    negative
# 4    positive
# Name: sentiment, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.head()
# Out:
# 35087    Obviously made to show famous 1950s stripper M...
# 8499     If this movie had been directed by a man, he w...
# 3254     Sergeant Ryker is accused of being a traitor d...
# 15350    To confess having fantasies about Brad Pitt is...
# 481      Things to Come is an early Sci-Fi film that sh...
# Name: review, dtype: object

# %%
X_train.shape
# Out:
# (35000,)

# %%
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

# %%
text_classifier = Pipeline([('tfidf', TfidfVectorizer(ngram_range=(1,2))), ('clf', LinearSVC())])

# %%
text_classifier.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#          steps=[('tfidf',
#                  TfidfVectorizer(analyzer='word', binary=False,
#                                  decode_error='strict',
#                                  dtype=<class 'numpy.float64'>,
#                                  encoding='utf-8', input='content',
#                                  lowercase=True, max_df=1.0, max_features=None,
#                                  min_df=1, ngram_range=(1, 2), norm='l2',
#                                  preprocessor=None, smooth_idf=True,
#                                  stop_words=None, strip_accents=None,
#                                  sublinear_tf=False,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, use_idf=True,
#                                  vocabulary=None)),
#                 ('clf',
#                  LinearSVC(C=1.0, class_weight=None, dual=True,
#                            fit_intercept=True, intercept_scaling=1,
#                            loss='squared_hinge', max_iter=1000,
#                            multi_class='ovr', penalty='l2', random_state=None,
#                            tol=0.0001, verbose=0))],
#          verbose=False)

# %%
predictions = text_classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.9198

# %%
text_classifier.predict(["It was a good movie, with a nice story"])
# Out:
# array(['positive'], dtype=object)

# %%
text_classifier.predict(["It wasn't a good movie, with really bad editing"])
# Out:
# array(['negative'], dtype=object)

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
analyzer = SentimentIntensityAnalyzer()

# %%
analyzer.polarity_scores("It was a good movie, with a nice story")
# Out:
# {'compound': 0.6908, 'neg': 0.0, 'neu': 0.467, 'pos': 0.533}

# %%
analyzer.polarity_scores("It wasn't a good movie, with really bad editing")
# Out:
# {'compound': -0.7351, 'neg': 0.508, 'neu': 0.492, 'pos': 0.0}
